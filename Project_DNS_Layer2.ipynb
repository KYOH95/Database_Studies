# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# #First 10% of DataSet
DF_chrome = pd.read_csv('dataset/chrome.csv',header=[0],nrows = 54546)
DF_firefox = pd.read_csv('dataset/firefox.csv',header=[0],nrows = 37183)
DF_dns2tcp = pd.read_csv('dataset/dns2tcp.csv',header=[0],nrows = 16751)
DF_dnscat2 = pd.read_csv('dataset/dnscat2.csv',header=[0],nrows = 3585)
DF_iodine = pd.read_csv('dataset/iodine.csv',header=[0],nrows = 4659)

# DF_chrome = pd.read_csv('dataset/chrome.csv',header=[0])
# DF_firefox = pd.read_csv('dataset/firefox.csv',header=[0])
# DF_dns2tcp = pd.read_csv('dataset/dns2tcp.csv',header=[0])
# DF_dnscat2 = pd.read_csv('dataset/dnscat2.csv',header=[0])
# DF_iodine = pd.read_csv('dataset/iodine.csv',header=[0])

# DF_nondoh = pd.read_csv('Total-CSVs/1-nondoh.csv',header=[0])
# DF_doh = pd.read_csv('Total-CSVs/1-doh.csv',header=[0])

# DF_benign = pd.read_csv('Total-CSVs/2-benign.csv',header=[0])
# DF_malicious = pd.read_csv('Total-CSVs/2-malicious.csv',header=[0])

# %%
DF_chrome.head()
# print(DF_chrome['SourceIP'].dtypes)
# Out:
#          SourceIP   DestinationIP  SourcePort  DestinationPort  \
# 0     72.21.91.42  192.168.20.191         443            51041
# 1  192.168.20.191  195.201.169.48       51043              443
# 2  192.168.20.191    96.17.115.57       51021              443
# 3  192.168.20.191   96.114.14.140       50308              443
# 4  192.168.20.191   23.78.199.198       50983              443
#
#              TimeStamp  Duration  FlowBytesSent  FlowSentRate  \
# 0  2020-01-14 15:49:01  4.544040       11256331  2.477164e+06
# 1  2020-01-14 15:49:03  8.171041            930  1.138166e+02
# 2  2020-01-14 15:49:03  0.033776            162  4.796305e+03
# 3  2020-01-14 15:49:03  0.060723            108  1.778568e+03
# 4  2020-01-14 15:49:03  0.019545             55  2.814019e+03
#
#    FlowBytesReceived  FlowReceivedRate  ...  PacketTimeCoefficientofVariation  \
# 0             159324      35062.191354  ...                          0.580949
# ...

# %%
# Out:
#              SourceIP    DestinationIP  SourcePort  DestinationPort  Duration  \
# 11299   54.239.180.40   192.168.20.191         443            55865  0.000000
# 6272   192.168.20.191   210.242.216.99       53727              443  0.228506
# 12758  192.168.20.191  178.154.131.215       56889              443  0.133358
# 28003  192.168.20.191  151.101.125.188       63169              443  0.025003
# 12021  192.168.20.191    40.77.226.250       56672              443  0.573748
# ...               ...              ...         ...              ...       ...
# 15983  192.168.20.191    13.225.146.17       57892              443  0.078939
# 54046  192.168.20.191   23.194.121.117       57664              443  5.701813
# 36275  192.168.20.191    172.217.0.246       50408              443  0.026922
# 23095  192.168.20.191   198.41.208.132       61206              443  0.015216
# 26466  192.168.20.191      172.64.97.5       62700              443  0.021446
#
# ...

# %%
DF_chrome = DF_chrome.drop(['TimeStamp'], axis=1)
DF_firefox = DF_firefox.drop(['TimeStamp'], axis=1)
DF_dns2tcp = DF_dns2tcp.drop(['TimeStamp'], axis=1)
DF_dnscat2 = DF_dnscat2.drop(['TimeStamp'], axis=1)
DF_iodine = DF_iodine.drop(['TimeStamp'], axis=1)

# %%
DF_chrome = DF_chrome.drop(DF_chrome[DF_chrome.DoH == True].index)

# %%
DF_chrome.true_count = (DF_iodine['DoH']).value_counts()[False]
print(true_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-729bf3be4c59> in <module>
#       1 DF_chrome.true_count = (DF_iodine['DoH']).value_counts()[False]
# ----> 2 print(true_count)
#
# NameError: name 'true_count' is not defined

# %%
#Add 'Malicious Column' which is the target attribute
DF_chrome['Malicious'] = 0
DF_firefox['Malicious'] = 0
DF_dns2tcp['Malicious'] = 1
DF_dnscat2['Malicious'] = 1
DF_iodine['Malicious'] = 1

# %%
DF_chrome.head()

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import mean_squared_error
from sklearn import metrics
